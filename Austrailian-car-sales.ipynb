# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 1.The Problem
# How to valuate a car in Australia
# # 2.Causes of the analysis
# This is to understand the car pricing in Australia

# %%
path = r'C:\Users\Administrator\Desktop\Data Science\practice data'
os.chdir(path)
df = pd.read_csv('Australian-Vehicle-Prices.csv')
df
# Out:
#                Brand    Year    Model               Car/Suv  \
# 0          Ssangyong  2022.0   Rexton  Sutherland Isuzu Ute
# 1                 MG  2022.0      MG3             Hatchback
# 2                BMW  2022.0     430I                 Coupe
# 3      Mercedes-Benz  2011.0     E500                 Coupe
# 4            Renault  2022.0   Arkana                   SUV
# ...              ...     ...      ...                   ...
# 16729         Toyota  2014.0  Alphard              SYC Cars
# 16730  Mercedes-Benz  2012.0  S-Class        USED Dealer ad
# 16731         Suzuki  2022.0   Vitara   Bremer Suzuki - New
# 16732  Mercedes-Benz  2016.0   GLC250                   SUV
# 16733  Mercedes-Benz  2021.0     C200                 Sedan
#
#                                            Title UsedOrNew Transmission  \
# 0           2022 Ssangyong Rexton Ultimate (awd)      DEMO    Automatic
# 1      2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# 2                          2022 BMW 430I M Sport      USED    Automatic
# 3               2011 Mercedes-Benz E500 Elegance      USED    Automatic
# 4                     2022 Renault Arkana Intens      USED    Automatic
# ...                                          ...       ...          ...
# 16729                        2014 Toyota Alphard      USED    Automatic
# 16730     2012 Mercedes-Benz S-Class CDI BlueTEC      USED    Automatic
# 16731                    2022 Suzuki Vitara 1.6L      DEMO    Automatic
# 16732                  2016 Mercedes-Benz GLC250      USED    Automatic
# 16733                    2021 Mercedes-Benz C200      USED    Automatic
#
#              Engine DriveType  FuelType FuelConsumption Kilometres  \
# 0      4 cyl, 2.2 L       AWD    Diesel  8.7 L / 100 km       5595
# 1      4 cyl, 1.5 L     Front   Premium  6.7 L / 100 km         16
# 2        4 cyl, 2 L      Rear   Premium  6.6 L / 100 km       8472
# 3      8 cyl, 5.5 L      Rear   Premium   11 L / 100 km     136517
# 4      4 cyl, 1.3 L     Front  Unleaded    6 L / 100 km       1035
# ...             ...       ...       ...             ...        ...
# 16729             -     Front  Unleaded               -      66000
# 16730             -      Rear    Diesel               -     117432
# 16731  4 cyl, 1.6 L     Front  Unleaded  6.2 L / 100 km       5165
# 16732    4 cyl, 2 L       AWD   Premium  7.2 L / 100 km      85525
# 16733    4 cyl, 2 L      Rear  Unleaded    7 L / 100 km      31852
#
#         ColourExtInt             Location CylindersinEngine    BodyType  \
# 0      White / Black       Caringbah, NSW             4 cyl         SUV
# 1      Black / Black       Brookvale, NSW             4 cyl   Hatchback
# 2       Grey / White        Sylvania, NSW             4 cyl       Coupe
# 3      White / Brown    Mount Druitt, NSW             8 cyl       Coupe
# 4       Grey / Black     Castle Hill, NSW             4 cyl         SUV
# ...              ...                  ...               ...         ...
# 16729       Grey / -         Rocklea, QLD                 -  Commercial
# 16730     Silver / -  Port Melbourne, VIC                 -         NaN
# 16731     Yellow / -         Dinmore, QLD             4 cyl         SUV
# 16732   Grey / Black          Albion, QLD             4 cyl         SUV
# 16733       Gold / -          Yatala, QLD             4 cyl       Sedan
#
#           Doors     Seats   Price
# 0       4 Doors   7 Seats   51990
# 1       5 Doors   5 Seats   19990
# 2       2 Doors   4 Seats  108988
# 3       2 Doors   4 Seats   32990
# 4       4 Doors   5 Seats   34990
# ...         ...       ...     ...
# 16729   7 Seats       NaN   29500
# 16730       NaN       NaN   39888
# 16731   4 Doors   5 Seats   35280
# 16732   4 Doors   5 Seats   41888
# 16733   4 Doors   5 Seats   65888
#
# [16734 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16734 entries, 0 to 16733
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              16733 non-null  object
#  1   Year               16733 non-null  float64
#  2   Model              16733 non-null  object
#  3   Car/Suv            16706 non-null  object
#  4   Title              16733 non-null  object
#  5   UsedOrNew          16733 non-null  object
#  6   Transmission       16733 non-null  object
#  7   Engine             16733 non-null  object
#  8   DriveType          16733 non-null  object
#  9   FuelType           16733 non-null  object
#  10  FuelConsumption    16733 non-null  object
#  11  Kilometres         16733 non-null  object
#  12  ColourExtInt       16733 non-null  object
#  13  Location           16284 non-null  object
#  14  CylindersinEngine  16733 non-null  object
#  15  BodyType           16452 non-null  object
#  16  Doors              15130 non-null  object
#  17  Seats              15029 non-null  object
#  18  Price              16731 non-null  object
# dtypes: float64(1), object(18)
# memory usage: 2.4+ MB

# %%
df.columns
# Out:
# Index(['Brand', 'Year', 'Model', 'Car/Suv', 'Title', 'UsedOrNew',
#        'Transmission', 'Engine', 'DriveType', 'FuelType', 'FuelConsumption',
#        'Kilometres', 'ColourExtInt', 'Location', 'CylindersinEngine',
#        'BodyType', 'Doors', 'Seats', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Brand                   1
# Year                    1
# Model                   1
# Car/Suv                28
# Title                   1
# UsedOrNew               1
# Transmission            1
# Engine                  1
# DriveType               1
# FuelType                1
# FuelConsumption         1
# Kilometres              1
# ColourExtInt            1
# Location              450
# CylindersinEngine       1
# BodyType              282
# Doors                1604
# Seats                1705
# Price                   3
# dtype: int64

# %%
df.describe()
# Out:
#                Year
# count  16733.000000
# mean    2016.229248
# std        5.247705
# min     1940.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2020.000000
# max     2023.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df['Brand'].value_counts())
print(df['Year'].value_counts())
print(df['Model'].value_counts())
print(df['DriveType'].value_counts())
print(df['Location'].value_counts())
print(df['UsedOrNew'].value_counts())
# Out:
# Brand
# Toyota      2692
# Hyundai     1230
# Mazda       1171
# Holden      1069
# Ford        1044
#             ...
# Tata           1
# Proton         1
# Saab           1
# Smart          1
# Polestar       1
# Name: count, Length: 72, dtype: int64
# Year
# 2018.0    1579
# 2019.0    1466
# 2017.0    1338
# 2022.0    1316
# 2023.0    1309
# 2020.0    1119
# 2016.0    1113
# 2021.0    1086
# 2015.0    1070
# 2014.0     864
# 2013.0     829
# 2012.0     681
# 2011.0     503
# 2010.0     443
# 2009.0     358
# 2008.0     309
# 2007.0     259
# 2006.0     210
# 2005.0     169
# 2004.0     113
# 2003.0      72
# 2002.0      62
# 2000.0      40
# 2001.0      36
# 1998.0      29
# 1999.0      26
# 1997.0       9
# 1994.0       9
# 1996.0       8
# 1993.0       6
# 1990.0       4
# 1989.0       4
# 1995.0       2
# 1985.0       2
# 1992.0       2
# 1981.0       2
# 1986.0       1
# 1991.0       1
# 1959.0       1
# 1984.0       1
# 1978.0       1
# Name: count, dtype: int64
# Model
# Hilux          430
# Ranger         398
# Corolla        395
# Landcruiser    370
# I30            364
#               ...
# ZR-V             1
# A190             1
# Roadster         1
# GLC350           1
# GLE53            1
# Name: count, Length: 765, dtype: int64
# DriveType
# Front    6937
# 4WD      3143
# AWD      3112
# Rear     2305
# Other     955
# Name: count, dtype: int64
# Location
# Minchinbury, NSW         989
# Blacktown, NSW           287
# Liverpool, NSW           254
# Hoppers Crossing, VIC    224
# Ringwood, VIC            214
#                         ...
# Hyde Park, SA              1
# Medindie Gardens, SA       1
# Goodwood, SA               1
# Beaudesert, QLD            1
# East Toowoomba, QLD        1
# Name: count, Length: 617, dtype: int64
# UsedOrNew
# USED    14731
# NEW      1215
# DEMO      506
# Name: count, dtype: int64

# %% [markdown]
# # 3.Data cleaning
# This is dropping unncessary columns and imputing values using mean,median and mode

# %%
df.isnull().sum()
# Out:
# Brand                   1
# Year                    1
# Model                   1
# Car/Suv                28
# Title                   1
# UsedOrNew               1
# Transmission            1
# Engine                  1
# DriveType               1
# FuelType                1
# FuelConsumption         1
# Kilometres              1
# ColourExtInt            1
# Location              450
# CylindersinEngine       1
# BodyType              282
# Doors                1604
# Seats                1705
# Price                   3
# dtype: int64

# %%
df.isnull().sum()/df.isnull().count().sort_values()*100 
#Getting the missing values per coulmn in percentages
# Out:
# Brand                 0.005976
# Year                  0.005976
# Model                 0.005976
# Car/Suv               0.167324
# Title                 0.005976
# UsedOrNew             0.005976
# Transmission          0.005976
# Engine                0.005976
# DriveType             0.005976
# FuelType              0.005976
# FuelConsumption       0.005976
# Kilometres            0.005976
# ColourExtInt          0.005976
# Location              2.689136
# CylindersinEngine     0.005976
# BodyType              1.685192
# Doors                 9.585275
# Seats                10.188837
# Price                 0.017928
# dtype: float64

# %%
#Identifying the duplicates
df.duplicated().sum()
df.drop_duplicates()
# Out:
#                Brand    Year    Model               Car/Suv  \
# 0          Ssangyong  2022.0   Rexton  Sutherland Isuzu Ute
# 1                 MG  2022.0      MG3             Hatchback
# 2                BMW  2022.0     430I                 Coupe
# 3      Mercedes-Benz  2011.0     E500                 Coupe
# 4            Renault  2022.0   Arkana                   SUV
# ...              ...     ...      ...                   ...
# 16729         Toyota  2014.0  Alphard              SYC Cars
# 16730  Mercedes-Benz  2012.0  S-Class        USED Dealer ad
# 16731         Suzuki  2022.0   Vitara   Bremer Suzuki - New
# 16732  Mercedes-Benz  2016.0   GLC250                   SUV
# 16733  Mercedes-Benz  2021.0     C200                 Sedan
#
#                                            Title UsedOrNew Transmission  \
# 0           2022 Ssangyong Rexton Ultimate (awd)      DEMO    Automatic
# 1      2022 MG MG3 Auto Excite (with Navigation)      USED    Automatic
# 2                          2022 BMW 430I M Sport      USED    Automatic
# 3               2011 Mercedes-Benz E500 Elegance      USED    Automatic
# 4                     2022 Renault Arkana Intens      USED    Automatic
# ...                                          ...       ...          ...
# 16729                        2014 Toyota Alphard      USED    Automatic
# 16730     2012 Mercedes-Benz S-Class CDI BlueTEC      USED    Automatic
# 16731                    2022 Suzuki Vitara 1.6L      DEMO    Automatic
# 16732                  2016 Mercedes-Benz GLC250      USED    Automatic
# 16733                    2021 Mercedes-Benz C200      USED    Automatic
#
#              Engine DriveType  FuelType FuelConsumption Kilometres  \
# 0      4 cyl, 2.2 L       AWD    Diesel  8.7 L / 100 km       5595
# 1      4 cyl, 1.5 L     Front   Premium  6.7 L / 100 km         16
# 2        4 cyl, 2 L      Rear   Premium  6.6 L / 100 km       8472
# 3      8 cyl, 5.5 L      Rear   Premium   11 L / 100 km     136517
# 4      4 cyl, 1.3 L     Front  Unleaded    6 L / 100 km       1035
# ...             ...       ...       ...             ...        ...
# 16729             -     Front  Unleaded               -      66000
# 16730             -      Rear    Diesel               -     117432
# 16731  4 cyl, 1.6 L     Front  Unleaded  6.2 L / 100 km       5165
# 16732    4 cyl, 2 L       AWD   Premium  7.2 L / 100 km      85525
# 16733    4 cyl, 2 L      Rear  Unleaded    7 L / 100 km      31852
#
#         ColourExtInt             Location CylindersinEngine    BodyType  \
# 0      White / Black       Caringbah, NSW             4 cyl         SUV
# 1      Black / Black       Brookvale, NSW             4 cyl   Hatchback
# 2       Grey / White        Sylvania, NSW             4 cyl       Coupe
# 3      White / Brown    Mount Druitt, NSW             8 cyl       Coupe
# 4       Grey / Black     Castle Hill, NSW             4 cyl         SUV
# ...              ...                  ...               ...         ...
# 16729       Grey / -         Rocklea, QLD                 -  Commercial
# 16730     Silver / -  Port Melbourne, VIC                 -         NaN
# 16731     Yellow / -         Dinmore, QLD             4 cyl         SUV
# 16732   Grey / Black          Albion, QLD             4 cyl         SUV
# 16733       Gold / -          Yatala, QLD             4 cyl       Sedan
#
#           Doors     Seats   Price
# 0       4 Doors   7 Seats   51990
# 1       5 Doors   5 Seats   19990
# 2       2 Doors   4 Seats  108988
# 3       2 Doors   4 Seats   32990
# 4       4 Doors   5 Seats   34990
# ...         ...       ...     ...
# 16729   7 Seats       NaN   29500
# 16730       NaN       NaN   39888
# 16731   4 Doors   5 Seats   35280
# 16732   4 Doors   5 Seats   41888
# 16733   4 Doors   5 Seats   65888
#
# [16734 rows x 19 columns]

# %%
#Dropping unnecessary columns
df.drop(columns=['Car/Suv','Title'],inplace=True)

# %%
#Droping the row which is completely null
row_with_null = df[df['Price'].isnull()].head(1)
row_with_null
df.drop(index=2391,inplace=True)

# %%
#converting the price column into numerics
print(df['Price'].dtype)
df['Price'] = pd.to_numeric(df['Price'].replace('[\$,]', '', regex=True), errors='coerce')
# Out:
# object
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13692\2502850114.py:3: SyntaxWarning: invalid escape sequence '\$'
#   df['Price'] = pd.to_numeric(df['Price'].replace('[\$,]', '', regex=True), errors='coerce')

# %%
from sklearn.impute import SimpleImputer 
#Displaying current average price
print('Average Price before imputation',df['Price'].median()) 
#Create a simple imputer for only the price column
price_imputer=SimpleImputer(missing_values=np.nan,strategy='median')
#Applying it to the price column
df['Price'] = price_imputer.fit_transform(df[['Price']])
print('Averange Price after imputation',df['Price'].median())
# Out:
# Average Price before imputation 29500.0
# Averange Price after imputation 29500.0

# %%
#Filling the null values
df['Location']=df['Location'].fillna(df['Location'].mode()[0])
df['Doors']=df['Doors'].fillna(df['Doors'].mode()[0])
df['Seats']=df['Seats'].fillna(df['Seats'].mode()[0])

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Brand                0
# Year                 0
# Model                0
# UsedOrNew            0
# Transmission         0
# Engine               0
# DriveType            0
# FuelType             0
# FuelConsumption      0
# Kilometres           0
# ColourExtInt         0
# Location             0
# CylindersinEngine    0
# BodyType             0
# Doors                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# # 4.Data Visualization
# This is to make the data readable and easy to analyze.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # The target column
# This tells us that most vehicles are in the range of 0 to 100000 Australian dollars.

# %%
import matplotlib.ticker as ticker
sns.histplot(df['Price'], kde=True )
plt.title("Distribution of Vehicle Prices")
plt.ticklabel_format(style='plain', axis='x')
plt.grid(True)
plt.xticks(rotation=90)
plt.xticks()
plt.show()

# %% [markdown]
# # Car price by the Brand

# %%
plt.figure(figsize=(14,16))
sns.barplot(x='Brand',y='Price',hue='Brand',data=df)
plt.grid(True)
plt.title('Car price by Brand')
plt.xlabel('Brands')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Car price by the year of manufacture

# %%
plt.figure(figsize=(14,16))
sns.barplot(x='Year',y='Price',hue='Year',data=df)
plt.grid(True)
plt.title('Car price by YOM')
plt.xlabel('Year')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,16))
sns.kdeplot(x='Location',y='Price',hue='Location',data=df)
plt.grid(True)
plt.title('Car price by Location')
plt.xlabel('Location')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 plt.figure(figsize=(14,16))
# ----> 2 sns.kdeplot(x='Location',y='Price',hue='Location',data=df)
#       3 plt.grid(True)
#       4 plt.title('Car price by Location')
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
#    1682 color = _default_color(method, hue, color, kwargs)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\_base.py:1084, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1079     if var_type not in allowed_types:
#    1080         err = (
#    1081             f"The {var} variable is {var_type}, but one of "
#    1082             f"{allowed_types} is required"
#    1083         )
# -> 1084         raise TypeError(err)
#    1086 # -- Get axis objects for each row in plot_data for type conversions and scaling
#    1088 facet_dim = {"x": "col", "y": "row"}
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %% [markdown]
# # Count plot of car condition

# %%
sns.countplot(x='UsedOrNew' , hue='UsedOrNew' , data=df, palette='Set2')
plt.xlabel('Car condition')
plt.ylabel('Count')
plt.title('Count per condition')
plt.show()

# %% [markdown]
# From the plot above Used vehicles dorminate the market followed by the new market the demo ones are the least

# %% [markdown]
# # Price vs Car condition

# %%
plt.figure(figsize=(8,16))
sns.boxplot(y='Price', hue='UsedOrNew' , data=df , palette='Set1')
plt.xlabel('Car Condition')
plt.ylabel('Price')
plt.title('Price per the condition of the car')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# New cars cost more compared to the other ones
